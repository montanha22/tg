# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tg import get_data_path

# %%
t = np.linspace(0, 150, num=150)
s = pd.Series(np.sin(t * 2 * np.pi / 30)) + 2
s.index.name = "index"
s.name = "sine"
s.plot()
# s.to_csv(get_data_path("raw/perfect_sine.csv"), index=True)
# Out:
# <AxesSubplot: xlabel='index'>

# %%
t = np.linspace(0, 150, num=150)
s = pd.Series(np.sin(t * 2 * np.pi / 30) + np.random.randn(t.size) / 5)  + 2
s.index.name = "index"
s.name = "sine"
s.plot()
# s.to_csv(get_data_path("raw/noisy_sine.csv"), index=True)
# Out:
# <AxesSubplot: xlabel='index'>

# %%
# def random_walk(
#     df, start_value=0, threshold=0.5, 
#     step_size=1, min_value=-np.inf, max_value=np.inf
# ):
#     previous_value = start_value
#     for index, row in df.iterrows():
#         if previous_value < min_value:
#             previous_value = min_value
#         if previous_value > max_value:
#             previous_value = max_value
#         probability = np.random.random()
#         if probability >= threshold:
#             df.loc[index, 'value'] = previous_value + step_size
#             step_size = 1. * step_size
#         else:
#             df.loc[index, 'value'] = previous_value - step_size
#             step_size = 1. * step_size
#         previous_value = df.loc[index, 'value']
#     return df

# %%
# x = random_walk(
#     pd.DataFrame(index=range(160)),
#     start_value=0, threshold=0.5,
#     step_size=0.1, min_value=-np.inf, max_value=np.inf
# )

# x.plot()
# x.rolling(11).mean().dropna().plot()
# Out:
# <AxesSubplot: >

# %%
homicides = pd.read_csv(get_data_path("raw/homicides.csv"))
homicides
# Out:
#        Month  Homicides
# 0    2007-01        526
# 1    2007-02        486
# 2    2007-03        640
# 3    2007-04        572
# 4    2007-05        466
# ..       ...        ...
# 155  2019-12        330
# 156  2020-01        349
# 157  2020-02        323
# 158  2020-03        372
# 159  2020-04        311
#
# [160 rows x 2 columns]
